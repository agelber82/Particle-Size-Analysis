# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
from scipy import stats
from matplotlib import pyplot as plt

# %%
filename = 'U1484A_Data.csv'
df = pd.read_csv(filename,header=1)
df.keys()
# Out:
# Index(['Exp', 'Site', 'Hole ', 'Core', 'Type', 'Section',
#        'Recovered length (m)', 'Curated length (m)', 'Top depth CSF-A (m)',
#        'Bottom depth CSF-A (m)', 'Top depth CSF-B (m)',
#        'Bottom depth CSF-B (m)', 'Sample', 'Mean (µm)', 'Median (µm)',
#        'Mode (µm)', 'SD (µm)', 'd10 (µm)', 'd50 (µm)', 'd90 (µm)', '4', '6',
#        '10', '32', '63', '125', '250', '500', '%Clay', '%Silt', '%Sand',
#        'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34',
#        'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37'],
#       dtype='object')

# %%
plt.figure()
plt.plot(df['Top depth CSF-A (m)'],df['Mean (µm)'])
plt.title('Relationship btwn Grain Size and Depth below Sea Floor', fontsize = 20)
plt.xlabel('Depth below Sea Floor', fontsize=16)
plt.ylabel('Mean Gran Size (µm)', fontsize=16)
# Out:
# <img src="data:image/png;base64,...">
